# %% [markdown]
# + Linear wavepacket, $\sigma$
# + Initial $\alpha=2$, small trucation
# + Wigner function

# %% [markdown]
# Documenting important information
# + Initial state, alpha

# %%
l=linspace(-pi, pi)
y=linspace(-0.4, 0.4)

# %%
plot(l, sin(l));
plot(y, y);
grid();
