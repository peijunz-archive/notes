# %%
A = load('truncated.npy')
A2 = load('untruncated.npy')

# %%
l = log10(A2.clip(1e-5))
cax = matshow(l, aspect=3);
xlabel('sites')
ylabel('time units')
colorbar(cax);

# %%
l = log10(A.clip(1e-5))
cax = matshow(l, aspect=3);
xlabel('sites')
ylabel('time units')
colorbar(cax);
